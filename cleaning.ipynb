# %%
import pandas as pd

# %%
# data from public citibike trip page

file = "Resources/JC-201901-citibike-tripdata.csv"

df = pd.read_csv(file)

df

# 19676 rows, 15 columbs - from 2019
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19671           853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
# 19672           936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
# 19673           653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
# 19674           960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
# 19675          1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
#        start station id start station name  start station latitude  \
# ...

# %%
#index
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
new_df = df[['tripduration', 'starttime', 'stoptime',
       'start station name', 'start station latitude',
       'start station longitude', 'end station name',
       'end station latitude', 'end station longitude', 'usertype',
       'birth year', 'gender']]
new_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19671           853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
# 19672           936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
# 19673           653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
# 19674           960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
# 19675          1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
#       start station name  start station latitude  start station longitude  \
# ...

# %%
new_df.index.name = "numbers"
print(new_df, "\n")

print(new_df.index.name)
#new_df.index.name
# Out:
#          tripduration                 starttime                  stoptime  \
# numbers
# 0                 201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                 505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                 756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3                1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4                1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...               ...                       ...                       ...
# 19671             853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
# 19672             936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
# 19673             653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
# 19674             960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
# 19675            1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
# ...

# %%
# only extracted first 500 rows because didn't want loading issues

newer_df = new_df.loc[0:500]
newer_df
# Out:
#          tripduration                 starttime                  stoptime  \
# numbers
# 0                 201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                 505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                 756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3                1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4                1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...               ...                       ...                       ...
# 496               511  2019-01-18 13:43:52.4060  2019-01-18 13:52:24.3500
# 497               262  2019-01-18 16:28:40.6720  2019-01-18 16:33:03.4040
# 498               225  2019-01-18 16:35:09.9760  2019-01-18 16:38:55.8450
# 499               263  2019-01-18 16:56:38.6920  2019-01-18 17:01:02.1140
# 500               398  2019-01-18 17:00:55.4490  2019-01-18 17:07:34.2400
#
# ...

# %%
# converting 
newer_df.to_csv("Resources/final_clean.csv")
